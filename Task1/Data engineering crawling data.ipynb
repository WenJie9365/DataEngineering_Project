# %% [markdown]
# ## apple

# %% [markdown]
# ##### iphone14

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url = 'https://shopee.com.my/api/v4/item/get?itemid=16785369620&shopid=304509804'

req = requests.get(url, headers=headers).json()

#print(req['data']['description'])

description = req['data']['description']
brand = req['data']['brand']

print(description)
print(brand)
# Out:
# iPhone 14 Pro. Capture incredible detail with a 48MP Main camera. Experience iPhone in a whole new way with Dynamic Island and Always-On display. Crash Detection, a new safety feature, calls for help when you can’t.
#
# Features:
# • 6.1-inch Super Retina XDR display featuring Always-On and ProMotion
# • Dynamic Island, a magical new way to interact with iPhone
# • 48MP Main camera for up to 4x greater resolution
# • Cinematic mode now in 4K Dolby Vision up to 30 fps
# • Action mode for smooth, steady, handheld videos
# • Vital safety technology — Crash Detection1 calls for help when you can’t
# • All-day battery life and up to 23 hours of video playback
# • A16 Bionic, the ultimate smartphone chip
# • Industry-leading durability features with Ceramic Shield and water resistance
# • iOS 16 offers even more ways to personalise, communicate and share
#
# What's in the box
# - iPhone 14 Pro
# - USB-C to Lightning Cable
#
# Apple

# %%
import json
import re
import requests
reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "delivery_service": [], "product_quality": [], "seller_service": [], "comment": []} 

url = 'https://shopee.com.my/Apple-iPhone-14-Pro-i.304509804.16785369620?sp_atk=7ce49252-2995-4135-930f-0d93a2051673&xptdk=7ce49252-2995-4135-930f-0d93a2051673'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username = rating['author_username']
        print(username)
        reviewlist["username"].append(username)
        
        star = rating['rating_star']
        print(star)
        reviewlist["rating"].append(star)
        
        reviewlist["brand"].append(brand)
        
        model = rating["product_items"][0]['name']
        print(model)
        reviewlist["model"].append(model)
        
        variation = rating["product_items"][0]['model_name']
        print(variation)
        reviewlist["variation"].append(variation)
        
        reviewlist["description"].append(description)
        
        delivery = rating["detailed_rating"]["delivery_service"]
        print(delivery)
        reviewlist["delivery_service"].append(delivery)
        
        quality = rating["detailed_rating"]["product_quality"]
        print(quality)
        reviewlist["product_quality"].append(quality)
        
        service = rating["detailed_rating"]["seller_service"]
        print(service)
        reviewlist["seller_service"].append(service)

        review = rating['comment']
        print(review)
        reviewlist["comment"].append(review)
        
        print('-' * 80)

    offset += 40
# Out:
# n*****s
# 5
# Apple iPhone 14 Pro
# Space Black,128GB
# 5
# 5
# 5
# Performance:High Quality & fast delivery
# Quality:Excellent
#
# Authentic products from Apple. Well packed and received in good condition. Good packaging and fast delivery from machines.
# --------------------------------------------------------------------------------
# mumys_baby
# 5
# Apple iPhone 14 Pro
# Deep Purple,256GB
# 5
# 5
# 5
# Performance:High
# Quality:Excellent
#
# Good product and recommended. Well packed and received in good terms without any damages.
# --------------------------------------------------------------------------------
# a*****m
# 5
# [Pre-order] Apple iPhone 14 Pro [ETA: TBC]
# Deep Purple,256GB
# 5
# 5
# 5
# Performance:high quality and faster delivery
#
# Masa preorder aritu tarikh eta takde lg.. nasib baik cpt smpai.. 🤣
# --------------------------------------------------------------------------------
# weeboonhee
# 5
# Apple iPhone 14 Pro
# Silver,128GB
# 5
# 5
# 5
# ...

# %% [markdown]
# ###### iphone11

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url2 = 'https://shopee.com.my/api/v4/item/get?itemid=4552579062&shopid=304504082'

req2 = requests.get(url2, headers=headers).json()

#print(req2['data']['description'])
description2 = req2['data']['description']
brand2 = req2['data']['brand']

print(description2)
print(brand2)
# Out:
# Shoot 4K videos, beautiful portraits, and sweeping landscapes with the all-new dual-camera system. Capture your best low-light photos with Night mode. See true-to-life color in your photos, videos, and games on the 6.1-inch Liquid Retina display. Experience unprecedented performance with A13 Bionic for gaming, augmented reality (AR), and photography. Do more and charge less with all-day battery life. And worry less with water resistance up to 2 meters for 30 minutes.
#
# Key feature
# • 6.1-inch Liquid Retina HD LCD display
# • Water and dust resistant (2 meters for up to 30 minutes, IP68)
# • Dual-camera system with 12MP Ultra Wide and Wide cameras; Night mode, Portrait mode, and 4K video up to 60fps
# • 12MP TrueDepth front camera with Portrait mode, 4K video, and Slo-Mo
# • Face ID for secure authentication and Apple Pay
# • A13 Bionic chip with third-generation Neural Engine
# • Fast-charge capable
# • Wireless charging
# ...

# %%
import json
import re
import requests

url = 'https://shopee.com.my/Apple-iPhone-11-128GB-i.304504082.4552579062?sp_atk=691865dd-1dd9-40c9-9ede-2419592ca6fb&xptdk=691865dd-1dd9-40c9-9ede-2419592ca6fb'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username2 = rating['author_username']
        print(username2)
        reviewlist["username"].append(username2)
        
        star2 = rating['rating_star']
        print(star2)
        reviewlist["rating"].append(star2)
        
        reviewlist["brand"].append(brand2)
        
        model2 = rating["product_items"][0]['name']
        print(model2)
        reviewlist["model"].append(model2)
        
        variation2 = rating["product_items"][0]['model_name']
        print(variation2)
        reviewlist["variation"].append(variation2)
        
        reviewlist["description"].append(description2)
        
        delivery2 = rating["detailed_rating"]["delivery_service"]
        print(delivery2)
        reviewlist["delivery_service"].append(delivery2)
        
        quality2 = rating["detailed_rating"]["product_quality"]
        print(quality2)
        reviewlist["product_quality"].append(quality2)
        
        service2 = rating["detailed_rating"]["seller_service"]
        print(service2)
        reviewlist["seller_service"].append(service2)

        review2 = rating['comment']
        print(review2)
        reviewlist["comment"].append(review2)
        
        print('-' * 80)

    offset += 40
# Out:
# c*****a
# 5
# Apple iPhone 11 128GB
# White
# 5
# 5
# 5
# Performance:Smooth.
# Quality:Genuine.
#
# Ordered 21/3, shipped on the same day and received on 22/3. Super fast shipping by seller and delivery by DHL eCommerce. Seller was responsive to my queries. Received the phone securely with thick bubble wraps together with the invoice. My iPhone 11 looks perfectly fine and I love it! Thank you Switch👍🏻
# --------------------------------------------------------------------------------
# fienaeddy
# 5
# Apple iPhone 11 128GB
# White
# 5
# 5
# 5
# Performance:terbaik dari apple
# Quality:good item
#
# Order 25hb.. Smpai 28hb.. penantian amat mendebarkan hihih..sebab risau kan item paling mahal yg pernah buat on9🤣
# Biasa beli kedai shj ...
# Tapi amat berpuas hati team Swift sentiasa update dan balas chat cepat..dan akan whspp Cust setelah terima item.jgn risau .. boleh beli disini dan yakin lah dgn produk apple 😘
# ...

# %% [markdown]
# # Vivo

# %% [markdown]
# ##### vivo T1 5G

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url3 = 'https://shopee.com.my/api/v4/item/get?itemid=16340800475&shopid=19049195'

req3 = requests.get(url3, headers=headers).json()

#print(req2['data']['description'])
description3 = req3['data']['description']
brand3 = req3['data']['brand']

print(description3)
print(brand3)
# Out:
# vivo T1 5G Highlight:
# Snapdragon 778G 5G Processor
# 8GB + 4GB Extended RAM
# 66W FlashCharge (50% FlashCharge In 18.2 Minutes)
# 4700mAh Large Battery
# 90 Hz Refresh Rate Amoled Display
# Chamber Cooling System
# 64MP Ai Triple Camera System + Super Night Mode + 4K Ultra HD Video
# Multi-Turbo 5.5
#
# Basic
# Processor: Snapdragon 778G 5G Processor
# RAM: 8GB + 4GB Extended RAM
# Storage: 128GB ROM
# Battery: 4700mAh(TYP)
# Color: Turbo Black, Turbo Cyan
# Operating System: Funtouch OS 12
#
# Body
# Dimensions: 159.7*73.6*8.49mm
# Weight: 180.3g
# Charging Power: 66W
# Material: 3D Plastic
#
# Display
# Screen: 6.44-inch
# Resolution: 2404*1080 (FHD+)
# Type: AMOLED
# Touch Screen: Capacitive multi-touch
#
# Network
# 4G
# 2G: GSM	850/900/1800/1900
# 3G: WCDMA	B1/B5/B8
# 4G: FDD-LTE	B1/B3/B5/B8
# 4G: TDD-LTE	B38/B40/B41 (2535~2655MHz)
# 5G
# NR NSA:	n41/n78
# NR SA*:	n1/n3/n5/n8/n41/n77 (3300~3800MHz)/n78
#
# Card Slot: Dual nano SIM
# Standby Mode: Dual SIM Dual Standby (DSDS)
# ...

# %%
import json
import re
import requests
#reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "comment": []}

url = 'https://shopee.com.my/vivo-T1-5G-Snapdragon-778G-5G-Processor-(66W-FlashCharge-Chamber-Cooling-System-64MP-Camera)-i.19049195.16340800475?sp_atk=dca36ced-3c20-461e-bb01-043f55fa8d90&xptdk=dca36ced-3c20-461e-bb01-043f55fa8d90'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username3 = rating['author_username']
        print(username3)
        reviewlist["username"].append(username3)
        
        star3 = rating['rating_star']
        print(star3)
        reviewlist["rating"].append(star3)
        
        reviewlist["brand"].append(brand3)
        
        model3 = rating["product_items"][0]['name']
        print(model3)
        reviewlist["model"].append(model3)
        
        variation3 = rating["product_items"][0]['model_name']
        print(variation3)
        reviewlist["variation"].append(variation3)
        
        reviewlist["description"].append(description3)
        
        delivery3 = rating["detailed_rating"]["delivery_service"]
        print(delivery3)
        reviewlist["delivery_service"].append(delivery3)
        
        quality3= rating["detailed_rating"]["product_quality"]
        print(quality3)
        reviewlist["product_quality"].append(quality3)
        
        service3 = rating["detailed_rating"]["seller_service"]
        print(service3)
        reviewlist["seller_service"].append(service3)

        review3 = rating['comment']
        print(review3)
        reviewlist["comment"].append(review3)
        
        print('-' * 80)

    offset += 40
# Out:
# a*****i
# 5
# vivo T1 5G Snapdragon 778G 5G Processor (66W FlashCharge/Chamber Cooling System/64MP Camera)
# Turbo Black
# 5
# 5
# 5
# satisfied kalau untuk sesiapa bajet dalam 1k.tak menyesal beli hp ni.makn game smooth, graphic dia cantik. color body dia mmg cun habis sometimes nampak mcm matte navy blue. ringan dan smooth. tinggal nak kena touch up screen protector. jangan awak hampakan saya ya, saya nak pakai awak lama ni. tq seller
# --------------------------------------------------------------------------------
# dintakishewa
# 5
# vivo T1 5G Snapdragon 778G 5G Processor (66W FlashCharge/Chamber Cooling System/64MP Camera)
# Turbo Cyan
# None
# 5
# None
# Performance:padu vivo T1 5G
# Quality:sangat nice Dan padu
#
# ...

# %% [markdown]
# ###### Vivo Y17

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url4 = 'https://shopee.com.my/api/v4/item/get?itemid=10580143038&shopid=285083792'

req4 = requests.get(url4, headers=headers).json()

#print(req2['data']['description'])
description4 = req4['data']['description']
brand4 = req4['data']['brand']

print(description4)
print(brand4)
# Out:
# Vivo Y17 6GB RAM + 128GB ROM - 6.35 Inch 13MP Triper Camera LTE
# Original SmartPhones
#
# ** Full set included**
# - Adapter x1
# - USB cable x1
#
# - SPEC -
# ** IPS LCD
# ** 6.35 inches, 99.6 cm2 (~81.4% screen-to-body ratio)
# ** Android 9.0 (Pie), Funtouch 9
# ** Mediatek MT6765 Helio P35 (12nm)
# ** Octa-core (4x2.3 GHz Cortex-A53 & 4x1.8 GHz Cortex-A53)
# ** microSDXC (dedicated slot)
# ** 128GB 6GB RAM
# ** 13 MP, f/2.2, PDAF
# ** 1080p@30fps
# ** 16 MP, f/2.0, 26mm (wide), 1/3.06", 1.0µm
# ** Wi-Fi 802.11 b/g/n, Wi-Fi Direct, hotspot
# ** Fingerprint (rear-mounted), accelerometer, proximity, compass
# ** Li-Po 5000 mAh, non-removable
# ** Fast charging 18W
#
# Original Vivo product.
# All the function working well.
# Can support any sim card.
# Good & Original quality , no disassembly or any modified.
#
# ** 100% NOT CLONE SET
# ** 100% REFUND IF CLONE SET
#
# (WARRANTY)
# These products covered with 1(ONE) Year limited warranty on SELLER only.
# ...

# %%
import json
import re
import requests
#reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "comment": []}

url = 'https://shopee.com.my/Vivo-Y17-6GB-RAM-128GB-ROM-6.35-Inch-13MP-LTE-(New)-With-1-Year-Warranty-Original-Smartphones-i.285083792.10580143038?sp_atk=7ce7896b-80bf-4d3b-8c90-87f5c28c99b8&xptdk=7ce7896b-80bf-4d3b-8c90-87f5c28c99b8'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username4 = rating['author_username']
        print(username4)
        reviewlist["username"].append(username4)
        
        star4 = rating['rating_star']
        print(star4)
        reviewlist["rating"].append(star4)
        
        reviewlist["brand"].append(brand4)
        
        model4 = rating["product_items"][0]['name']
        print(model4)
        reviewlist["model"].append(model4)
        
        variation4 = rating["product_items"][0]['model_name']
        print(variation4)
        reviewlist["variation"].append(variation4)
        
        reviewlist["description"].append(description4)
        
        delivery4 = rating["detailed_rating"]["delivery_service"]
        print(delivery4)
        reviewlist["delivery_service"].append(delivery4)
        
        quality4= rating["detailed_rating"]["product_quality"]
        print(quality4)
        reviewlist["product_quality"].append(quality4)
        
        service4 = rating["detailed_rating"]["seller_service"]
        print(service4)
        reviewlist["seller_service"].append(service4)

        review4 = rating['comment']
        print(review4)
        reviewlist["comment"].append(review4)
        
        print('-' * 80)

    offset += 40
# Out:
# n*****s
# 4
# Vivo Y17 6GB RAM + 128GB ROM 6.35 Inch 13MP LTE (New) With 1 Year Warranty Original Smartphones
# SKY BLUE,6GB RAM + 128GB ROM
# 4
# 4
# 4
# Performance:boleh lah
# Quality:boleh lah
#
# Order warna sky blue sampai warna pink.. layankan aje
# --------------------------------------------------------------------------------
# angahaddie83
# 5
# Vivo Y17 6GB RAM + 128GB ROM 6.35 Inch 13MP LTE (New) With 1 Year Warranty Original Smartphones
# BLACK,6GB RAM + 128GB ROM
# 5
# 5
# 5
# Performance:Berfungsi dengan baik
# Quality:Terbaik
#
# Berfungsi dgn baik. Barang diterima dengan selamat. Software original Vivo. Thank you seller.
# --------------------------------------------------------------------------------
# may_0516
# 5
# Vivo Y17 6GB RAM + 128GB ROM 6.35 Inch 13MP LTE (New) With 1 Year Warranty Original Smartphones
# PURPLE,6GB RAM + 128GB ROM
# 5
# 5
# 5
# Packaging are perfect and not damaged. Overall is good for now.
# ...

# %% [markdown]
# ###### oppo

# %% [markdown]
# ###### #OPPO-RENO-7-PRO

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url5 = 'https://shopee.com.my/api/v4/item/get?itemid=16277084179&shopid=745658536'

req5 = requests.get(url5, headers=headers).json()

#print(req2['data']['description'])
description5 = req5['data']['description']
brand5 = 'Oppo'

print(description5)
print(brand5 )
# Out:
# Product of details
#
# - 12gb ram
# - 512gb rom
# - Face beauty camera
# - Face Unlock
# - Android 14.0
# - Camera rear 21MP
# - Camera front 21MP
# - Battery 4500 MAH
# - Dual sim dual standby
# - Bluetooth/wifi/gps/hotspot
# - Quad-core Processor
# - Colour : Black, Green, Gold
#
# FREE GIFT AVAILABLE
#
# - 1 x Sreen Protector
# - 1 x Silicon Cover
# - 1 x Phone Device
# - 1 x Battery
# - 1 x Cable
# - 1 x Charger
# - 1 x Handfree
#
# IMPORTANT NOTICE : THIS IS NEW OEM SET. PLEASE DUN COMPARE N EXPECT TO GET ORIGINAL WITH THIS PRICE.
#                                        WE ARE NOT ACCEPT ANY REFUNDABLE. THANK YOU VERY MUCH
# Oppo

# %%
import json
import re
import requests
#reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "comment": []}

url = 'https://shopee.com.my/-OFFER-ITEMS-OPPO-RENO-7-PRO-12GB-512GB-4G-LTE-ANDROID-SMART-PHONE-i.745658536.16277084179?xptdk=70635b6d-f947-4867-a711-39d6e8ba0647'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username5 = rating['author_username']
        print(username5)
        reviewlist["username"].append(username5)
        
        star5 = rating['rating_star']
        print(star5)
        reviewlist["rating"].append(star5)
        
        reviewlist["brand"].append(brand5)
        
        model5 = rating["product_items"][0]['name']
        print(model5)
        reviewlist["model"].append(model5)
        
        variation5 = rating["product_items"][0]['model_name']
        print(variation5)
        reviewlist["variation"].append(variation5)
        
        reviewlist["description"].append(description5)
        
        delivery5 = rating["detailed_rating"]["delivery_service"]
        print(delivery5)
        reviewlist["delivery_service"].append(delivery5)
        
        quality5= rating["detailed_rating"]["product_quality"]
        print(quality5)
        reviewlist["product_quality"].append(quality5)
        
        service5 = rating["detailed_rating"]["seller_service"]
        print(service5 )
        reviewlist["seller_service"].append(service5 )

        review5 = rating['comment']
        print(review5)
        reviewlist["comment"].append(review5)
        
        print('-' * 80)

    offset += 40
# Out:
# m*****j
# 5
# [OFFER ITEMS] OPPO RENO 7 PRO 12GB/512GB 4G LTE ANDROID SMART PHONE
# RENO 7 PRO
# None
# 5
# None
# Tqvm seller barang sudah selamat smpai di tangan dengan jaya nya.. barang dalam keadaan ok semua
# --------------------------------------------------------------------------------
# e*****v
# 5
# [OFFER ITEMS] OPPO RENO 7 PRO 12GB/512GB 4G LTE ANDROID SMART PHONE
# RENO 7 PRO
# None
# 5
# None
# Design & color mmg cun👍👍😍😍so far okay guna cuma sedikit slow bila nak on overall semua okay..mampu milk👏👏
# --------------------------------------------------------------------------------
# j*****v
# 5
# [OFFER ITEMS] OPPO RENO 7 PRO 12GB/512GB 4G LTE ANDROID SMART PHONE
# RENO 7 PRO
# None
# 5
# None
# Barang sampai pantas dan packing kemas.. thanks sellers.. thanks recommend 👍👍
# --------------------------------------------------------------------------------
# e*****v
# 5
# [OFFER ITEMS] OPPO RENO 7 PRO 12GB/512GB 4G LTE ANDROID SMART PHONE
# RENO 7 PRO
# None
# 5
# None
# ...

# %% [markdown]
# ##### OPPO A96

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url6 = 'https://shopee.com.my/api/v4/item/get?itemid=10791939153&shopid=12017474'

req6 = requests.get(url6, headers=headers).json()

#print(req2['data']['description'])
description6 = req6['data']['description']
brand6 = req6['data']['brand']

print(description6)
print(brand6 )
# Out:
# In the Box:
# OPPO A96 x 1
# USB cable x 1
# Charger x 1
# SIM ejector tool x 1
# Protective case x 1
# Quick start guide x 1
# Warranty card x 1
# Oppo

# %%
import json
import re
import requests
#reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "comment": []}

url = 'https://shopee.com.my/OPPO-A96-Smartphone-8GB-RAM-256-GB-ROM-33W-SUPERVOOC-90Hz-Colour-Rich-Punch-Hole-Display-i.12017474.10791939153?sp_atk=3ab28b3e-0b18-470d-bc7a-477a7b2226b2&xptdk=3ab28b3e-0b18-470d-bc7a-477a7b2226b2'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username6 = rating['author_username']
        print(username6)
        reviewlist["username"].append(username6)
        
        star6 = rating['rating_star']
        print(star6)
        reviewlist["rating"].append(star6)
        
        reviewlist["brand"].append(brand6)
        
        model6 = rating["product_items"][0]['name']
        print(model6)
        reviewlist["model"].append(model6)
        
        variation6 = rating["product_items"][0]['model_name']
        print(variation6)
        reviewlist["variation"].append(variation6)
        
        reviewlist["description"].append(description6)
        
        delivery6 = rating["detailed_rating"]["delivery_service"]
        print(delivery6)
        reviewlist["delivery_service"].append(delivery6)
        
        quality6= rating["detailed_rating"]["product_quality"]
        print(quality6)
        reviewlist["product_quality"].append(quality6)
        
        service6 = rating["detailed_rating"]["seller_service"]
        print(service6 )
        reviewlist["seller_service"].append(service6 )

        review6 = rating['comment']
        print(review6)
        reviewlist["comment"].append(review6)
        
        print('-' * 80)

    offset += 40
# Out:
# eikyn
# 5
# OPPO A96 Smartphone | 8GB+ 256GB | 33W SUPERVOOC | 5000mAh Long-Lasting Battery | 90Hz Colour-Rich Punch-Hole Display
# Promo-Black
# 5
# 5
# 5
# Performance:so far so good
# Quality:oppo
#
# Kesian kotak camtu sekali...
# Barang dtrma dalam keadaan baik.. beli time 2.2 banyak less... Setakat ni function ok
# --------------------------------------------------------------------------------
# a*****1
# 5
# OPPO A96 Smartphone | 8GB+ 256GB | 33W SUPERVOOC | 5000mAh Long-Lasting Battery | 90Hz Colour-Rich Punch-Hole Display
# Pearl Pink
# 5
# 5
# 5
# Safe and quality packaging to protect the phone. Nice colour and currently exploring how to use it. Thanks! 🙏
# --------------------------------------------------------------------------------
# y*****g
# 5
# [FIRST- SALE] OPPO A96 Smartphone | 8GB RAM + 256 GB ROM | 33W SUPERVOOC | 5000mAh Long-Lasting Battery | 90 Hz Colour
# Pink-Special Promo
# None
# 5
# None
# 第二次购买Oppo 手机
# 觉得好用才会选择Oppo
# 幸好能在生日前收到
# 还有赠品哦 谢谢Oppo
# ...

# %% [markdown]
# # samsung

# %% [markdown]
# ###### Samsung Galaxy M12

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url7 = 'https://shopee.com.my/api/v4/item/get?itemid=6286974981&shopid=131102790'

req7 = requests.get(url7, headers=headers).json()

#print(req2['data']['description'])
description7 = req7['data']['description']
brand7 = req7['data']['brand']

print(description7)
print(brand7)
# Out:
# 1 Year Samsung Malaysia Warranty
#
# Highlights
#
# - 6.5" HD+ TFT, 90Hz Refresh Rate
# - Android 10,ONE UI 2 (TBC)
# - Octa-Core
# - Exynos 850
# - 4GB RAM + 64GB Storage
# - microSD up to 1TB
# - Rear Camera : 48MP (F2.0) + 5MP Ultra Wide (F2.2) + 2MP Depth (F2.4) +  2MP Macro (F2.4)
# - Front Camera: 8MP (F2.2)
# - 5,000mAh
# - Bluetooth v5.0
# - 802.11 b/g/n 2.4GHz, Wi-Fi Direct
# - Dual SIM
# - Accelerometer, Fingerprint
#
# What's In The Box
#
# - 1 x Samsung Galaxy M12
# - 1 x Travel Adapter
# - 1 x Cable (Type-C)
# - 1 x Pin
# - 1 x User Guide
# Samsung

# %%
import json
import re
import requests
#reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "comment": []}

url = 'https://shopee.com.my/Samsung-Galaxy-M12-Android-Handphone-90Hz-Refresh-Rate-Blue-Green-(4GB-RAM-64GB-ROM-6.5-)-i.131102790.6286974981?sp_atk=bf2c5820-24aa-4a75-b5d0-8f8b19e8ecdb'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username7 = rating['author_username']
        print(username7)
        reviewlist["username"].append(username7)
        
        star7 = rating['rating_star']
        print(star7)
        reviewlist["rating"].append(star7)
        
        reviewlist["brand"].append(brand7)
        
        model7 = rating["product_items"][0]['name']
        print(model7)
        reviewlist["model"].append(model7)
        
        variation7 = rating["product_items"][0]['model_name']
        print(variation7)
        reviewlist["variation"].append(variation7)
        
        reviewlist["description"].append(description7)
        
        delivery7 = rating["detailed_rating"]["delivery_service"]
        print(delivery7)
        reviewlist["delivery_service"].append(delivery7)
        
        quality7= rating["detailed_rating"]["product_quality"]
        print(quality7)
        reviewlist["product_quality"].append(quality7)
        
        service7 = rating["detailed_rating"]["seller_service"]
        print(service7 )
        reviewlist["seller_service"].append(service7 )

        review7 = rating['comment']
        print(review7)
        reviewlist["comment"].append(review7)
        
        print('-' * 80)

    offset += 40
# Out:
# y*****d
# 5
# Samsung Galaxy M12 Android Handphone 90Hz Refresh Rate - Blue/Green (4GB RAM/64GB ROM/6.5")
# Blue
# None
# 5
# None
# Alhamdulillah... Henpon telah selamat diterima.
# Thanks seller. Thanks shoppe. Thanks JnT.
#
# Update:
# Korg kalau beli, belilah siap² casing, screen protector & etc.. Sebab samsung mmg tak bagi walau basic accessories sekali pun.
# Accessories boleh pakai samsung galaxy A12 punya.
#
# Happy shopping..
# --------------------------------------------------------------------------------
# buyoutpro
# 5
# Samsung Galaxy M12 Android Handphone 90Hz Refresh Rate - Blue/Green (4GB RAM/64GB ROM/6.5")
# Green
# None
# 5
# None
# Bersyukur dengan limpah nikmat dariNya saya telah mendapatkan smartphone untuk anak lelaki saya bagi mencapai cita2nya menjadi seorang PUBG Yang berkaliber. Jika Batu loncatan ini menunjukkan keharmonian Dan kejayaan, saya akan menaiktaraf bantuan smartphonenya kepada tahap yang lebih memuaskan. 💯
# ...

# %% [markdown]
# ##### Samsung Galaxy Z FLIP

# %%
import requests
import json 
import pandas as pd

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

url8 = 'https://shopee.com.my/api/v4/item/get?itemid=10032464140&shopid=54618012'

req8 = requests.get(url8, headers=headers).json()

#print(req2['data']['description'])
description8 = req8['data']['description']
brand8 = req8['data']['brand']

print(description8)
print(brand8)
# Out:
# ***********
#  Please remark your NAME and PHONE NO. during check out for warranty registration purpose.
# ***********
#
# Galaxy Z Flip 3
# Basic
# -Full Set Device Only
#
# Set A
# -Full Set Device
# -Original Samsung Galaxy Buds Live [Black] worth RM549
# [1 Year Warranty under Samsung Malaysia]
#
# Galaxy Z Flip 4
# Basic
# - Full set device only
# - Camera Filter Mount worth RM169
# - 1 year extended warranty & 3x Protective Film Replacement worth RM499
# [total 2 years Screen Coverage: 1 year standard warranty + 1 year extended warranty]**
#
# Set A
# - Full set device
# - Camera Filter Mount worth RM169
# - Galaxy Flip4 Flap Leather Cover worth RM379
# - 1 year extended warranty & 3x Protective Film Replacement worth RM499
# [total 2 years Screen Coverage: 1 year standard warranty + 1 year extended warranty]**
#
# *3 Protective Film Replacement*
# ...

# %%
import json
import re
import requests
#reviewlist = {"username": [], "rating": [], "brand": [], "model": [], "variation": [], "description": [], "comment": []}

url = 'https://shopee.com.my/Samsung-Galaxy-Z-FLIP-4-5G-Z-FLIP-3-5G-Smartphone-Original-Malaysia-New-Set-1-Year-Warranty-i.54618012.10032464140?sp_atk=b073f1ca-f19e-4750-a39f-38a2cd5c8eb9&xptdk=b073f1ca-f19e-4750-a39f-38a2cd5c8eb9'

r = re.search(r'i\.(\d+)\.(\d+)', url)
shop_id, item_id = r[1], r[2]
ratings_url = 'https://shopee.com.my/api/v2/item/get_ratings?filter=0&flag=1&itemid={item_id}&limit=20&offset={offset}&shopid={shop_id}&type=0'
offset = 0 


while True:
    
    data = requests.get(ratings_url.format(shop_id=shop_id, item_id=item_id, offset=offset)).json()
    
    
    i = 1
    for i, rating in enumerate(data['data']['ratings'], 1):
        
        username8 = rating['author_username']
        print(username8)
        reviewlist["username"].append(username8)
        
        star8 = rating['rating_star']
        print(star8)
        reviewlist["rating"].append(star8)
        
        reviewlist["brand"].append(brand8)
        
        model8 = rating["product_items"][0]['name']
        print(model8)
        reviewlist["model"].append(model8)
        
        variation8 = rating["product_items"][0]['model_name']
        print(variation8)
        reviewlist["variation"].append(variation8)
        
        reviewlist["description"].append(description8)
        
        delivery8 = rating["detailed_rating"]["delivery_service"]
        print(delivery8)
        reviewlist["delivery_service"].append(delivery8)
        
        quality8= rating["detailed_rating"]["product_quality"]
        print(quality8)
        reviewlist["product_quality"].append(quality8)
        
        service8 = rating["detailed_rating"]["seller_service"]
        print(service8 )
        reviewlist["seller_service"].append(service8 )

        review8 = rating['comment']
        print(review8)
        reviewlist["comment"].append(review8)
        
        print('-' * 80)

    offset += 40
# Out:
# norainiadnan7871
# 5
# Samsung Galaxy Z FLIP 3 5G (8GB+128GB) / (8GB+256GB) / Z Flip (8GB+256GB) Smartphone
# Z Flip Basic,256GB- Black
# 3
# 5
# 4
# Performance:works
# Quality:good
#
# The item was received safely, with delivery from shopee express which was quite disappointing... The item was only wrapped with normal bubble wrap, it is quite expensive with the premium package.. Worth Rm74. like a normal package, it should be packed with a box that has security..
# --------------------------------------------------------------------------------
# nwpp0506
# 5
# [PRE-ORDER] Samsung Galaxy Z FLIP 3 5G (8GB+128GB) / (8GB+256GB) Smartphone
# Lavender,256GB
# None
# 5
# None
# Very good packaging. Genuine product. Sales service is good as well. Will buy from them again if needed. And super fast delivery. Received in 2 days
# --------------------------------------------------------------------------------
# s*****w
# 5
# ...

# %% [markdown]
# ##### save to csv

# %%
import pandas as pd
df = pd.DataFrame(reviewlist)
df.to_csv(r'reviewDataTest.csv', index=False)
print('End.')
# Out:
# End.

# %%
  print(df.head()) # print only the head for brevity
# Out:
#      username  rating  brand  \
# 0     n*****s       5  Apple
# 1  mumys_baby       5  Apple
# 2     a*****m       5  Apple
# 3  weeboonhee       5  Apple
# 4     a*****n       5  Apple
#
#                                                model          variation  \
# 0                                Apple iPhone 14 Pro  Space Black,128GB
# 1                                Apple iPhone 14 Pro  Deep Purple,256GB
# 2         [Pre-order] Apple iPhone 14 Pro [ETA: TBC]  Deep Purple,256GB
# 3                                Apple iPhone 14 Pro       Silver,128GB
# 4  [Pre-order] Apple iPhone 14 Pro [ETA: 6 weeks ...  Deep Purple,128GB
#
#                                          description  delivery_service  \
# 0  iPhone 14 Pro. Capture incredible detail with ...               5.0
# 1  iPhone 14 Pro. Capture incredible detail with ...               5.0
# 2  iPhone 14 Pro. Capture incredible detail with ...               5.0
# ...

# %%
df.count()
# Out:
# username            3513
# rating              3535
# brand               3535
# model               3535
# variation           3535
# description         3535
# delivery_service     660
# product_quality     3535
# seller_service       660
# comment             3535
# dtype: int64
